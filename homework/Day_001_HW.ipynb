# %% [markdown]
# 作業1：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# https://www.kaggle.com/c/LANL-Earthquake-Prediction?&utm_medium=email&utm_source=intercom&utm_campaign=jan-news-comp-launch
# 1. 你選的這組資料為何重要
# 根據實際地震數據預測實驗室地震發生前的剩餘時間。如果這一挑戰得以解決，物理學最終可以從實驗室擴展到現場，
# 研究人員將有可能改進可以挽救生命和數十億美元基礎設施的地震災害評估。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 數據來自Los Alamos National Laboratory用於研究地震物理學的著名實驗裝置。
#
# 3. 蒐集而來的資料型態為何
# 數據欄位
# acoustic_data  - 地震信號[int16]
# time_to_failure  - 直到下一次實驗室地震的時間（以秒為單位）[float64]
# seg_id  - 應對其進行預測的測試段ID（每個段一個預測）
#
# 4. 這組資料想解決的問題如何評估
# 使用在下一次實驗地震之前剩餘的預測時間與實際發生的剩餘時間之間的平均絕對誤差來評估

# %% [markdown]
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 根據氣象與時段推測出需要較多搭車的人(如：火車站)，派遣司機預先到達可能有較多搭車需求的地點，提供運送服務。
# 後續可能還可以根據需求而派出對應的車型(如：航站搭車的人會有大、小包行李，需要較大車型的車子)，暫時先不加入這個部分。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 由氣象局的資料可以得到天氣預報與實際的天氣資料。另外，車子中也會有記錄車子移動的GPS資料，輔以搭車的起始和到達地點與車資等資料。
#
# 3. 蒐集而來的資料型態為何
# 出發地點(GPS 經緯度) float,float
# 到達地點(GPS 經緯度) float,float
# 星期幾(日~六) int
# 時刻(幾點幾分) time
# 天氣(晴天、陰天、雨天) int
# 車資 int
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 根據天氣預報和日期、時段來派遣車子到預估會有較多搭乘需求的地點來等候乘車，經過一段時間(如：一周或一個月)來評估實際的收入與過去相比較。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

def mean_squared_error(y,y_hat):
    """
    請完成這個 Function 後往下執行
    """
    """
    計算 MSE
    Args:
        - y: 實際值
        - y_hat: 平均值
    Return:
        - mae: MAE
    """
    mse = MSE = sum((y - y_hat)**2) / len(y)
    return mse

#MSE = mean_squared_error(y, y_hat)
#print("The Mean Square Error is %.3f" % (MSE))

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 234.835
# The Mean absolute error is 11.836
